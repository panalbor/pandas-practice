# %% [markdown]
# # Завдання 3-1. GroupBy

# %% [markdown]
# ### Вступ:
#
# GroupBy можна узагальнити як "Розділити-Застосувати-Об'єднати" (Split-Apply-Combine).
#
# Джерело датасету: https://github.com/justmarkham.
#
# Для кращого розуміння погляньте на [діаграму](http://i.imgur.com/yjNkiwL.png)
# ### 1. Імпортуйте потрібні бібліотеки

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Імпортуйте датасет [звідси](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### 3. Призначте його змінній drinks.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"
drinks = pd.read_csv(url)

# %%
drinks.head(15)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# 13         Bangladesh              0                0              0
# 14           Barbados            143              173             36
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 1                            4.9        EU
# 2                            0.7        AF
# 3                           12.4        EU
# 4                            5.9        AF
# 5                            4.9       NaN
# 6                            8.3        SA
# 7                            3.8        EU
# 8                           10.4        OC
# 9                            9.7        EU
# 10                           1.3        EU
# 11                           6.3       NaN
# 12                           2.0        AS
# 13                           0.0        AS
# 14                           6.3       NaN

# %% [markdown]
# ### 4. Який континент споживає найбільше пива (в середньому по країнам)?

# %%
gb_cont = drinks.groupby('continent')

# %%
gb_cont.agg({'beer_servings': 'mean'})\
       .sort_values('beer_servings', ascending=False)\
       .reset_index()\
       .loc[0, 'continent']
# Out:
# 'EU'

# %% [markdown]
# ### 5. Для кожного континенту надрукуйте статистику споживання вина.

# %%
gb_cont.wine_servings.describe().reset_index()
# Out:
#   continent  count        mean        std  min   25%    50%     75%    max
# 0        AF   53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# 1        AS   44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# 2        EU   45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# 3        OC   16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# 4        SA   12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### 6. Надрукуйте середнє споживання алкоголю на континентах (для кожного стовпця)

# %%
gb_cont.agg(np.mean)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Крок 7. Надрукуйте медіану кількості споживання алкоголю на континентах (для кожного стовпця)

# %%
gb_cont.agg(np.median)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### 8. Надрукуйте середнє, мінімальне та максимальне значення споживання спиртних напоїв по континентам (spirit servings)

# %%
gb_cont.spirit_servings.describe()[['mean', 'min', 'max']]
# Out:
#                  mean   min    max
# continent
# AF          16.339623   0.0  152.0
# AS          60.840909   0.0  326.0
# EU         132.555556   0.0  373.0
# OC          58.437500   0.0  254.0
# SA         114.750000  25.0  302.0

# %%
drinks[['spirit_servings']]
# Out:
#      spirit_servings
# 0                  0
# 1                132
# 2                  0
# 3                138
# 4                 57
# ..               ...
# 188              100
# 189                2
# 190                0
# 191               19
# 192               18
#
# [193 rows x 1 columns]
